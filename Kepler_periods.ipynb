# %%
# Out:
# ^C
#   DEPRECATION: Building 'fbpca' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'fbpca'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   DEPRECATION: Building 'memoization' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'memoization'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# Collecting lightkurve
#   Downloading lightkurve-2.5.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting astropy>=5.0 (from lightkurve)
#   Downloading astropy-7.2.0-cp311-abi3-win_amd64.whl.metadata (11 kB)
# Collecting astroquery>=0.3.10 (from lightkurve)
#   Downloading astroquery-0.4.11-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from lightkurve) (4.12.3)
# Collecting bokeh>=2.3.2 (from lightkurve)
#   Downloading bokeh-3.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting fbpca>=1.0 (from lightkurve)
#   Downloading fbpca-1.0.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting matplotlib>=3.1 (from lightkurve)
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting memoization>=0.3.1 (from lightkurve)
#   Downloading memoization-0.4.0.tar.gz (41 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting numpy>=1.26 (from lightkurve)
#   Downloading numpy-2.4.1-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting pandas>=1.3.6 (from lightkurve)
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting patsy>=0.5.0 (from lightkurve)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: requests>=2.22.0 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from lightkurve) (2.32.3)
# Collecting s3fs>=2024.6.1 (from lightkurve)
#   Downloading s3fs-2026.1.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting scikit-learn>=0.24.0 (from lightkurve)
#   Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy>=1.7 (from lightkurve)
#   Downloading scipy-1.17.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: tqdm>=4.25.0 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from lightkurve) (4.67.1)
# Collecting uncertainties>=3.1.4 (from lightkurve)
#   Downloading uncertainties-3.2.4-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3>=1.23 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from lightkurve) (2.4.0)
# Collecting pyerfa>=2.0.1.1 (from astropy>=5.0->lightkurve)
#   Downloading pyerfa-2.0.1.5-cp39-abi3-win_amd64.whl.metadata (5.9 kB)
# Collecting astropy-iers-data>=0.2025.10.27.0.39.10 (from astropy>=5.0->lightkurve)
#   Downloading astropy_iers_data-0.2026.1.12.0.42.13-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from astropy>=5.0->lightkurve) (6.0.2)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from astropy>=5.0->lightkurve) (25.0)
# Collecting html5lib>=0.999 (from astroquery>=0.3.10->lightkurve)
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting keyring>=15.0 (from astroquery>=0.3.10->lightkurve)
#   Downloading keyring-25.7.0-py3-none-any.whl.metadata (21 kB)
# Collecting pyvo>=1.5 (from astroquery>=0.3.10->lightkurve)
#   Downloading pyvo-1.8-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from beautifulsoup4>=4.6.0->lightkurve) (2.5)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from bokeh>=2.3.2->lightkurve) (3.1.6)
# Collecting contourpy>=1.2 (from bokeh>=2.3.2->lightkurve)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting narwhals>=1.13 (from bokeh>=2.3.2->lightkurve)
#   Downloading narwhals-2.15.0-py3-none-any.whl.metadata (13 kB)
# Collecting pillow>=7.1.0 (from bokeh>=2.3.2->lightkurve)
#   Downloading pillow-12.1.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: tornado>=6.2 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from bokeh>=2.3.2->lightkurve) (6.5.1)
# Collecting xyzservices>=2021.09.1 (from bokeh>=2.3.2->lightkurve)
#   Downloading xyzservices-2025.11.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six>=1.9 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from Jinja2>=2.9->bokeh>=2.3.2->lightkurve) (3.0.2)
# Collecting pywin32-ctypes>=0.2.0 (from keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Using cached pywin32_ctypes-0.2.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting jaraco.classes (from keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Using cached jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jaraco.functools (from keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Downloading jaraco_functools-4.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting jaraco.context (from keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Downloading jaraco_context-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.1->lightkurve)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.1->lightkurve)
#   Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.1->lightkurve)
#   Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.1->lightkurve)
#   Downloading pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from matplotlib>=3.1->lightkurve) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.3.6->lightkurve)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.3.6->lightkurve)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from requests>=2.22.0->lightkurve) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from requests>=2.22.0->lightkurve) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from requests>=2.22.0->lightkurve) (2025.4.26)
# Collecting aiobotocore<4.0.0,>=2.5.4 (from s3fs>=2024.6.1->lightkurve)
#   Downloading aiobotocore-3.1.0-py3-none-any.whl.metadata (26 kB)
# Collecting fsspec==2026.1.0 (from s3fs>=2024.6.1->lightkurve)
#   Downloading fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from s3fs>=2024.6.1->lightkurve)
#   Downloading aiohttp-3.13.3-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<4.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve)
#   Downloading aioitertools-0.13.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting botocore<1.42.20,>=1.41.0 (from aiobotocore<4.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve)
#   Downloading botocore-1.42.19-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<4.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve)
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting multidict<7.0.0,>=6.0.0 (from aiobotocore<4.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve)
#   Downloading multidict-6.7.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting wrapt<3.0.0,>=1.10.10 (from aiobotocore<4.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve)
#   Downloading wrapt-2.0.1-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (24.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve)
#   Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve)
#   Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve)
#   Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl.metadata (77 kB)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from aiosignal>=1.4.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (4.12.2)
# Collecting joblib>=1.3.0 (from scikit-learn>=0.24.0->lightkurve)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn>=0.24.0->lightkurve)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\smithlt\.julia\conda\3\x86_64\lib\site-packages (from tqdm>=4.25.0->lightkurve) (0.4.6)
# Collecting more-itertools (from jaraco.classes->keyring>=15.0->astroquery>=0.3.10->lightkurve)
#   Using cached more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Downloading lightkurve-2.5.1-py3-none-any.whl (256 kB)
# Downloading astropy-7.2.0-cp311-abi3-win_amd64.whl (6.4 MB)
#    ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#    ---------------- ----------------------- 2.6/6.4 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.4 MB 14.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.4/6.4 MB 11.8 MB/s eta 0:00:00
# Downloading astropy_iers_data-0.2026.1.12.0.42.13-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 11.0 MB/s eta 0:00:00
# Downloading astroquery-0.4.11-py3-none-any.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ----------- ---------------------------- 3.1/11.1 MB 14.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.1 MB 14.3 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.1 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 14.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 12.9 MB/s eta 0:00:00
# Downloading bokeh-3.8.2-py3-none-any.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ----------- ---------------------------- 2.1/7.2 MB 11.8 MB/s eta 0:00:01
#    ------------------------ --------------- 4.5/7.2 MB 11.2 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 10.3 MB/s eta 0:00:00
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading keyring-25.7.0-py3-none-any.whl (39 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.1 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 9.2 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    --------------------------- ------------ 1.6/2.3 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 6.9 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Downloading narwhals-2.15.0-py3-none-any.whl (432 kB)
# Downloading numpy-2.4.1-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/12.3 MB 10.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.4/12.3 MB 8.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.3 MB 9.1 MB/s eta 0:00:01
#    ------------------------- -------------- 7.9/12.3 MB 9.5 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.3 MB 9.2 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 8.9 MB/s eta 0:00:00
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading pillow-12.1.0-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------- ----------------------- 2.9/7.0 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.0 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 12.8 MB/s eta 0:00:00
# Downloading pyerfa-2.0.1.5-cp39-abi3-win_amd64.whl (349 kB)
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading pyvo-1.8-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 10.6 MB/s eta 0:00:00
# Using cached pywin32_ctypes-0.2.3-py3-none-any.whl (30 kB)
# Downloading s3fs-2026.1.0-py3-none-any.whl (30 kB)
# Downloading fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Downloading aiobotocore-3.1.0-py3-none-any.whl (87 kB)
# Downloading aiohttp-3.13.3-cp312-cp312-win_amd64.whl (455 kB)
# Downloading aioitertools-0.13.0-py3-none-any.whl (24 kB)
# Downloading botocore-1.42.19-py3-none-any.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/14.6 MB 9.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.9/14.6 MB 10.2 MB/s eta 0:00:02
#    ------------------ --------------------- 6.6/14.6 MB 10.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.7/14.6 MB 10.5 MB/s eta 0:00:01
#    ------------------------------ --------- 11.0/14.6 MB 10.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.8/14.6 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 9.9 MB/s eta 0:00:00
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading multidict-6.7.0-cp312-cp312-win_amd64.whl (46 kB)
# Downloading wrapt-2.0.1-cp312-cp312-win_amd64.whl (60 kB)
# Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -------------- ------------------------- 2.9/8.0 MB 13.9 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.0 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 12.4 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.0-cp312-cp312-win_amd64.whl (36.3 MB)
#    ---------------------------------------- 0.0/36.3 MB ? eta -:--:--
#    -- ------------------------------------- 2.1/36.3 MB 10.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.5/36.3 MB 10.8 MB/s eta 0:00:03
#    ------- -------------------------------- 6.8/36.3 MB 11.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.2/36.3 MB 11.0 MB/s eta 0:00:03
#    ------------ --------------------------- 11.3/36.3 MB 11.0 MB/s eta 0:00:03
#    -------------- ------------------------- 13.1/36.3 MB 10.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 14.9/36.3 MB 10.6 MB/s eta 0:00:03
#    ------------------- -------------------- 17.6/36.3 MB 10.6 MB/s eta 0:00:02
#    --------------------- ------------------ 19.9/36.3 MB 10.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 21.8/36.3 MB 10.7 MB/s eta 0:00:02
#    -------------------------- ------------- 24.1/36.3 MB 10.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 26.5/36.3 MB 10.8 MB/s eta 0:00:01
#    ------------------------------- -------- 28.8/36.3 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 31.2/36.3 MB 10.8 MB/s eta 0:00:01
#    ------------------------------------- -- 33.8/36.3 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  35.9/36.3 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.3 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 36.3/36.3 MB 10.3 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Downloading uncertainties-3.2.4-py3-none-any.whl (60 kB)
# Downloading xyzservices-2025.11.0-py3-none-any.whl (93 kB)
# Using cached jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Downloading jaraco_context-6.1.0-py3-none-any.whl (7.1 kB)
# Downloading jaraco_functools-4.4.0-py3-none-any.whl (10 kB)
# Using cached more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Building wheels for collected packages: fbpca, memoization
#   Building wheel for fbpca (setup.py): started
#   Building wheel for fbpca (setup.py): finished with status 'done'
#   Created wheel for fbpca: filename=fbpca-1.0-py3-none-any.whl size=11444 sha256=fdd240eebde9649ab95024ed3048d6acfafb0069c8ce98cbc704bf3ef2c263b3
#   Stored in directory: c:\users\smithlt\appdata\local\pip\cache\wheels\04\15\cd\2f622795b09e83471a3be5d2581cd9cf96a6ec7aa78e8deffe
#   Building wheel for memoization (setup.py): started
#   Building wheel for memoization (setup.py): finished with status 'done'
#   Created wheel for memoization: filename=memoization-0.4.0-py3-none-any.whl size=50601 sha256=e6ae34b1f42e7b8773cb23246c0952f4e26b329b674cb815c97324106bc88652
#   Stored in directory: c:\users\smithlt\appdata\local\pip\cache\wheels\26\35\02\90618fc7cbf03a335f3cacd59d32b35930bf5a57f3c0d0814c
# Successfully built fbpca memoization
# Installing collected packages: pytz, fbpca, xyzservices, wrapt, uncertainties, tzdata, threadpoolctl, pywin32-ctypes, pyparsing, propcache, pillow, numpy, narwhals, multidict, more-itertools, memoization, kiwisolver, joblib, jmespath, jaraco.context, html5lib, fsspec, frozenlist, fonttools, cycler, astropy-iers-data, aioitertools, aiohappyeyeballs, yarl, scipy, pyerfa, patsy, pandas, jaraco.functools, jaraco.classes, contourpy, botocore, aiosignal, scikit-learn, matplotlib, keyring, bokeh, astropy, aiohttp, pyvo, aiobotocore, s3fs, astroquery, lightkurve
#
#    ----------------------------------------  0/49 [pytz]
#    ----------------------------------------  0/49 [pytz]
#    ----------------------------------------  0/49 [pytz]
#    ----------------------------------------  0/49 [pytz]
#    - --------------------------------------  2/49 [xyzservices]
#    -- -------------------------------------  3/49 [wrapt]
#    -- -------------------------------------  3/49 [wrapt]
#    -- -------------------------------------  3/49 [wrapt]
#    --- ------------------------------------  4/49 [uncertainties]
#    --- ------------------------------------  4/49 [uncertainties]
#    --- ------------------------------------  4/49 [uncertainties]
#    ---- -----------------------------------  5/49 [tzdata]
#    ---- -----------------------------------  5/49 [tzdata]
#    ---- -----------------------------------  6/49 [threadpoolctl]
#    ----- ----------------------------------  7/49 [pywin32-ctypes]
#    ----- ----------------------------------  7/49 [pywin32-ctypes]
#    ----- ----------------------------------  7/49 [pywin32-ctypes]
#    ----- ----------------------------------  7/49 [pywin32-ctypes]
#    ----- ----------------------------------  7/49 [pywin32-ctypes]
#    ----- ----------------------------------  7/49 [pywin32-ctypes]
#    ----- ----------------------------------  7/49 [pywin32-ctypes]
#    ------ ---------------------------------  8/49 [pyparsing]
#    ------ ---------------------------------  8/49 [pyparsing]
#    ------ ---------------------------------  8/49 [pyparsing]
#    ------ ---------------------------------  8/49 [pyparsing]
#    ------- --------------------------------  9/49 [propcache]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 10/49 [pillow]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    -------- ------------------------------- 11/49 [numpy]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    --------- ------------------------------ 12/49 [narwhals]
#    ---------- ----------------------------- 13/49 [multidict]
#    ----------- ---------------------------- 14/49 [more-itertools]
#    ----------- ---------------------------- 14/49 [more-itertools]
#    ------------ --------------------------- 15/49 [memoization]
#    ------------ --------------------------- 15/49 [memoization]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    ------------- -------------------------- 17/49 [joblib]
#    -------------- ------------------------- 18/49 [jmespath]
#    -------------- ------------------------- 18/49 [jmespath]
#    -------------- ------------------------- 18/49 [jmespath]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ---------------- ----------------------- 20/49 [html5lib]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 21/49 [fsspec]
#    ----------------- ---------------------- 22/49 [frozenlist]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    ------------------ --------------------- 23/49 [fonttools]
#    -------------------- ------------------- 25/49 [astropy-iers-data]
#    -------------------- ------------------- 25/49 [astropy-iers-data]
#    --------------------- ------------------ 26/49 [aioitertools]
#    --------------------- ------------------ 26/49 [aioitertools]
#    --------------------- ------------------ 26/49 [aioitertools]
#    --------------------- ------------------ 26/49 [aioitertools]
#    ---------------------- ----------------- 27/49 [aiohappyeyeballs]
#    ---------------------- ----------------- 27/49 [aiohappyeyeballs]
#    ---------------------- ----------------- 28/49 [yarl]
#    ---------------------- ----------------- 28/49 [yarl]
#    ---------------------- ----------------- 28/49 [yarl]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
#    ----------------------- ---------------- 29/49 [scipy]
# ...
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ---------------------------------- ----- 42/49 [astropy]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 43/49 [aiohttp]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ----------------------------------- ---- 44/49 [pyvo]
#    ------------------------------------ --- 45/49 [aiobotocore]
#    ------------------------------------ --- 45/49 [aiobotocore]
#    ------------------------------------ --- 45/49 [aiobotocore]
#    ------------------------------------ --- 45/49 [aiobotocore]
#    ------------------------------------ --- 45/49 [aiobotocore]
#    ------------------------------------ --- 45/49 [aiobotocore]
#    ------------------------------------ --- 45/49 [aiobotocore]
#    ------------------------------------ --- 45/49 [aiobotocore]
#    ------------------------------------ --- 45/49 [aiobotocore]
#    ------------------------------------ --- 45/49 [aiobotocore]
#    ------------------------------------- -- 46/49 [s3fs]
#    ------------------------------------- -- 46/49 [s3fs]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    -------------------------------------- - 47/49 [astroquery]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------  48/49 [lightkurve]
#    ---------------------------------------- 49/49 [lightkurve]
#
# Successfully installed aiobotocore-3.1.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aioitertools-0.13.0 aiosignal-1.4.0 astropy-7.2.0 astropy-iers-data-0.2026.1.12.0.42.13 astroquery-0.4.11 bokeh-3.8.2 botocore-1.42.19 contourpy-1.3.3 cycler-0.12.1 fbpca-1.0 fonttools-4.61.1 frozenlist-1.8.0 fsspec-2026.1.0 html5lib-1.1 jaraco.classes-3.4.0 jaraco.context-6.1.0 jaraco.functools-4.4.0 jmespath-1.0.1 joblib-1.5.3 keyring-25.7.0 kiwisolver-1.4.9 lightkurve-2.5.1 matplotlib-3.10.8 memoization-0.4.0 more-itertools-10.8.0 multidict-6.7.0 narwhals-2.15.0 numpy-2.4.1 pandas-2.3.3 patsy-1.0.2 pillow-12.1.0 propcache-0.4.1 pyerfa-2.0.1.5 pyparsing-3.3.1 pytz-2025.2 pyvo-1.8 pywin32-ctypes-0.2.3 s3fs-2026.1.0 scikit-learn-1.8.0 scipy-1.17.0 threadpoolctl-3.6.0 tzdata-2025.3 uncertainties-3.2.4 wrapt-2.0.1 xyzservices-2025.11.0 yarl-1.22.0

# %%
# %matplotlib inline
import lightkurve as lk
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
search_result = lk.search_lightcurve('KIC 3733346', author='Kepler')
search_result
# Out:
# SearchResult containing 18 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 01 2009 Kepler    1800 kplr003733346      0.0
#   1 Kepler Quarter 02 2009 Kepler    1800 kplr003733346      0.0
#   2 Kepler Quarter 03 2009 Kepler    1800 kplr003733346      0.0
#   3 Kepler Quarter 04 2010 Kepler    1800 kplr003733346      0.0
#   4 Kepler Quarter 05 2010 Kepler    1800 kplr003733346      0.0
#   5 Kepler Quarter 06 2010 Kepler    1800 kplr003733346      0.0
#   6 Kepler Quarter 07 2010 Kepler    1800 kplr003733346      0.0
#   7 Kepler Quarter 11 2011 Kepler      60 kplr003733346      0.0
#   8 Kepler Quarter 10 2011 Kepler    1800 kplr003733346      0.0
#   9 Kepler Quarter 09 2011 Kepler    1800 kplr003733346      0.0
#  10 Kepler Quarter 08 2011 Kepler    1800 kplr003733346      0.0
#  11 Kepler Quarter 11 2012 Kepler    1800 kplr003733346      0.0
#  12 Kepler Quarter 12 2012 Kepler    1800 kplr003733346      0.0
#  13 Kepler Quarter 13 2012 Kepler    1800 kplr003733346      0.0
#  14 Kepler Quarter 14 2012 Kepler    1800 kplr003733346      0.0
#  15 Kepler Quarter 15 2013 Kepler    1800 kplr003733346      0.0
#  16 Kepler Quarter 16 2013 Kepler    1800 kplr003733346      0.0
#  17 Kepler Quarter 17 2013 Kepler    1800 kplr003733346      0.0

# %%
lc = search_result.download()
lc
# Out:
# c:\Users\smithlt\miniconda3\envs\astr502\Lib\site-packages\lightkurve\search.py:424: LightkurveWarning: Warning: 18 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(
# <KeplerLightCurve length=1626 LABEL="KIC 3733346" QUARTER=1 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#        time             flux      ...   pos_corr1      pos_corr2
#                     electron / s  ...      pix            pix
#        Time           float32     ...    float32        float32
# ------------------ -------------- ... -------------- --------------
# 131.51288740462041  9.4774297e+04 ...  2.6976008e-02 -6.2739752e-02
#  131.5333220084649  8.7980359e+04 ...  2.6956452e-02 -6.2362801e-02
# 131.55375651219947  9.0003555e+04 ...  2.6780181e-02 -6.2061526e-02
# 131.57419091569318  8.9820125e+04 ...  2.6723903e-02 -6.2085036e-02
# 131.59462541919493  8.7733945e+04 ...  2.7358035e-02 -6.1654005e-02
#  131.6150600224646  8.5401805e+04 ...  2.7274568e-02 -6.1929043e-02
# 131.63549442573276  8.4559680e+04 ...  2.7174480e-02 -6.1837804e-02
# 131.65592892876157  8.8083414e+04 ...  2.7329614e-02 -6.1844509e-02
#   131.676363531682  1.0372423e+05 ...  2.7275356e-02 -6.1620597e-02
#                ...            ... ...            ...            ...
# 164.82088729622774  9.8839430e+04 ... -3.4264006e-02  7.8153342e-02
# 164.84132137458073  9.7419055e+04 ... -3.4402896e-02  7.8953095e-02
# 164.86175565292797  9.6565680e+04 ... -3.4848832e-02  7.9631776e-02
# 164.88218983081606  9.6034969e+04 ... -3.5440013e-02  8.0131195e-02
# 164.90262390847056  9.5584773e+04 ... -3.4574233e-02  7.9549290e-02
#  164.9230580858857  8.7143219e+04 ... -3.5529040e-02  7.9722576e-02
# 164.94349236307607  9.5417430e+04 ... -3.4583151e-02  7.9640768e-02
# 164.96392644003208  9.7040453e+04 ... -3.4845807e-02  8.0935009e-02
#  164.9843606165232  9.6912656e+04 ... -3.5944819e-02  8.1280954e-02

# %%
lc.plot()
plt.savefig('C:/Users/smithlt/Documents/ASTR502/test_light_curve.png')  # Current directory

# %%
lc_collection = search_result[:5].download_all()
lc_collection
# Out:
# LightCurveCollection of 5 objects:
#     0: <KeplerLightCurve LABEL="KIC 3733346" QUARTER=1 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     1: <KeplerLightCurve LABEL="KIC 3733346" QUARTER=2 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     2: <KeplerLightCurve LABEL="KIC 3733346" QUARTER=3 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     3: <KeplerLightCurve LABEL="KIC 3733346" QUARTER=4 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#     4: <KeplerLightCurve LABEL="KIC 3733346" QUARTER=5 AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>

# %%
fig, ax = plt.subplots(figsize=(20,5))
lc_collection.plot(ax=ax)
plt.savefig('C:/Users/smithlt/Documents/ASTR502/test_light_curve_collection.png')

# %%
print(lc.time)

print(lc.flux)
# Out:
# [131.5128874  131.53332201 131.55375651 ... 164.94349236 164.96392644
#  164.98436062]
# [94774.3   87980.36  90003.555 ... 95417.43  97040.45  96912.66 ] electron / s

# %%
#initial Lomb-Scargle attempt, returns NaN values for the power
time = lc['time'].value
flux = lc['flux'].value

print(time)
print(flux)

frequency, power = LombScargle(time, flux).autopower(minimum_frequency=1/20, maximum_frequency=10)

print(frequency)
print(power)
# Out:
# [131.51301737 131.53345175 131.55388603 ... 164.94325559 164.96368945
#  164.98412341]
# [11251.106 11256.095 11254.514 ... 11245.176 11252.992 11241.3  ]
# [0.05       0.0559753  0.06195061 ... 9.98692887 9.99290417 9.99887948]
# [nan nan nan ... nan nan nan]

# %%
from astropy.timeseries import LombScargle
import astropy.units as u

# convert to plain numpy arrays (strip astropy Quantity units if present)
time = lc.time.value if hasattr(lc.time, "value") else np.asarray(lc.time)
flux = lc.flux.value if hasattr(lc.flux, "value") else np.asarray(lc.flux)

# remove NaNs / infinities
mask = np.isfinite(time) & np.isfinite(flux)
time = time[mask]
flux = flux[mask]

frequency, power = LombScargle(time, flux).autopower(minimum_frequency=1/20, maximum_frequency=10)

print(frequency)
print(power)
# Out:
# [0.05       0.05597524 0.06195047 ... 9.98681987 9.9927951  9.99877034]
# [2.87605090e-05 2.23151354e-05 6.74511116e-06 ... 8.93185494e-06
#  1.03214138e-05 1.17524955e-05]

# %%
#fig, ax = plt.subplots()
plt.plot(1/frequency, power)
plt.xlabel('Period (days)')
plt.ylabel('Power')
plt.title('Lomb-Scargle Periodogram')
plt.xlim(0, 1.5) #changed the bounds to more accurately determine the period
plt.savefig('C:/Users/smithlt/Documents/ASTR502/test_lomb_scargle_periodogram.png')
plt.show()

# %%
#identifying the period that corresponds to the highest peak in the Lomb-Scargle periodogram
peak_frequency = frequency[np.argmax(power)]
peak_power = 1 / peak_frequency

print(f"Identified period: {peak_power} days")
# Out:
# Identified period: 0.682067163956709 days

# %%
import io

# Let's test several different search methods to see what works
print("Testing different lightkurve search methods...")

# Try the one you already know works
print("\n1. Testing with your known working target:")
search_result = lk.search_lightcurve('KIC 3733346', author='Kepler')
print(f"   'KIC 3733346': {len(search_result)} results")

# Try different formats
print("\n2. Testing different search formats:")
test_targets = [
    'KIC 3733346',
    '3733346', 
    'KIC 10666592',
    '10666592',
    'KIC 8191672',
    '8191672',
    'Kepler-1',
    'Kepler-2',
    'HAT-P-7',
    'TrES-2'
]

working_targets = []
for target in test_targets:
    try:
        result = lk.search_lightcurve(target, author='Kepler')
        print(f"   '{target}': {len(result)} results")
        if len(result) > 0:
            working_targets.append(target)
    except Exception as e:
        print(f"   '{target}': Error - {e}")

print(f"\n✓ Working targets found: {working_targets}")

# If we found working targets, create a CSV with those
if working_targets:
    print("\nCreating CSV with working targets...")
    
    # Create a simple CSV with verified working targets
    working_csv = "target_name,search_term\n"
    for target in working_targets[:5]:  # Take first 5 working targets
        working_csv += f"Target-{target.replace(' ', '')},{target}\n"
    
    star_df = pd.read_csv(io.StringIO(working_csv))
    print("CSV data loaded successfully!")
    print(f"Shape: {star_df.shape}")
    print("\nWorking targets:")
    for i, row in star_df.iterrows():
        print(f"  {row['target_name']}: {row['search_term']}")
else:
    print("No working targets found - there may be a deeper issue with the lightkurve installation or Kepler archive access")
# Out:
# Testing different lightkurve search methods...
#
# 1. Testing with your known working target:
#    'KIC 3733346': 18 results
#
# 2. Testing different search formats:
#    'KIC 3733346': 18 results
#    '3733346': 18 results
#    '3733346': 18 results
#    'KIC 10666592': 67 results
#    'KIC 10666592': 67 results
#    '10666592': 67 results
#    '10666592': 67 results
#    'KIC 8191672': 51 results
#    'KIC 8191672': 51 results
#    '8191672': 51 results
#    '8191672': 51 results
#    'Kepler-1': 53 results
#    'Kepler-1': 53 results
#    'Kepler-2': 67 results
#    'Kepler-2': 67 results
#    'HAT-P-7': 67 results
#    'HAT-P-7': 67 results
#    'TrES-2': 53 results
#
# ✓ Working targets found: ['KIC 3733346', '3733346', 'KIC 10666592', '10666592', 'KIC 8191672', '8191672', 'Kepler-1', 'Kepler-2', 'HAT-P-7', 'TrES-2']
#
# Creating CSV with working targets...
# CSV data loaded successfully!
# Shape: (5, 2)
#
# Working targets:
#   Target-KIC3733346: KIC 3733346
#   Target-3733346: 3733346
#   Target-KIC10666592: KIC 10666592
#   Target-10666592: 10666592
#   Target-KIC8191672: KIC 8191672
#    'TrES-2': 53 results
#
# ✓ Working targets found: ['KIC 3733346', '3733346', 'KIC 10666592', '10666592', 'KIC 8191672', '8191672', 'Kepler-1', 'Kepler-2', 'HAT-P-7', 'TrES-2']
#
# Creating CSV with working targets...
# CSV data loaded successfully!
# Shape: (5, 2)
#
# Working targets:
#   Target-KIC3733346: KIC 3733346
#   Target-3733346: 3733346
#   Target-KIC10666592: KIC 10666592
#   Target-10666592: 10666592
#   Target-KIC8191672: KIC 8191672

# %%
# Since we can't read the CSV file directly from the virtual file system,
# let's use a subset of real data from your mega target list
# I'll include some targets that might have Kepler data

import io

# Sample from your actual mega target list - focusing on targets that might have Kepler data
# These are real entries from your CSV file
mega_target_sample = """pl_name,hostname,gaia_dr3_id,gaia_dr2_id,tic_id,hd_name,ra,dec,sy_vmag,sy_jmag,sy_kmag,sy_tmag,sy_kepmag,sy_gaiamag,st_teff,st_logg,st_met,st_mass,st_rad,st_spectype,st_lum,st_age,st_ageerr1,st_ageerr2,st_rotp,pl_orbper,pl_rade,pl_trandur,disc_facility,disc_year,mission_source
HD 3167 b,HD 3167,Gaia DR3 2554032474712538880,Gaia DR2 2554032474712538880,TIC 318707987,HD 3167,8.7401487,4.3807215,8.97,7.548,7.066,8.2491,8.945,8.76221,5261.0,4.53,0.04,0.837,0.88,K0 V,-0.27003,7.8,4.3,-4.3,23.52,0.959641,1.67,1.609,K2,2016,K2
HD 3167 c,HD 3167,Gaia DR3 2554032474712538880,Gaia DR2 2554032474712538880,TIC 318707987,HD 3167,8.7401487,4.3807215,8.97,7.548,7.066,8.2491,8.945,8.76221,5261.0,4.53,0.04,0.837,0.88,K0 V,-0.27003,7.8,4.3,-4.3,23.52,29.8454,3.0,4.869,K2,2016,K2
K2-149 b,K2-149,Gaia DR3 2557342829345854208,Gaia DR2 2557342829345854208,TIC 429035886,,9.8217519,7.2769939,14.543,11.452,10.561,12.7422,13.787,13.7795,3745.0,4.707,0.11,0.595,0.568,M1.0 V,-1.3098,,,,,11.332,1.64,,K2,2018,K2
K2-206 b,K2-206,Gaia DR3 2549096011101118080,Gaia DR2 2549096011101118080,TIC 257392778,,11.2564264,0.5931866,13.084,11.439,10.918,12.2619,12.826,12.8274,5043.0,4.46,-0.14,0.789481,0.758046,,-0.43502,,,,,18.294549,2.79522879,,K2,2018,K2
K2-217 b,K2-217,Gaia DR3 2556248536102683008,Gaia DR2 2556248536102683008,TIC 405333767,,11.2983678,6.4815879,12.264,11.009,10.679,11.601,12.062,12.0279,5967.0,4.17,0.04,1.102661,1.333718,,0.23239,,,,,14.074524,3.57854073,5.688,K2,2018,K2"""

target_df = pd.read_csv(io.StringIO(mega_target_sample))
print("Loaded sample from mega target list!")
print(f"Shape: {target_df.shape}")
print(f"Targets with mission_source 'K2': {len(target_df[target_df['mission_source'] == 'K2'])}")

# Show the targets we'll search for
print("\nTargets to search for K2 data:")
for i, row in target_df.iterrows():
    print(f"  {row['pl_name']}: {row['tic_id']} (discovered by {row['mission_source']})")

# Test searching for these targets
print("\nTesting searches...")
working_targets = []

for i, row in target_df.iterrows():
    target_name = row['pl_name']
    tic_id = row['tic_id']
    
    # Try multiple search strategies
    search_terms = [
        f"{tic_id}",
        f"{tic_id}",
        target_name.split()[0] if len(target_name.split()) > 1 else target_name  # Get base name like "K2-149"
    ]
    
    for search_term in search_terms:
        try:
            result_k2 = lk.search_lightcurve(search_term, author='K2')
            
            total_results = len(result_k2)
            
            if total_results > 0:
                print(f"✓ {search_term}: {len(result_k2)} K2 results")
                working_targets.append({
                    'target_name': target_name,
                    'search_term': search_term,
                    'tic_id': tic_id,
                    'k2_results': len(result_k2)
                })
                break  # Found data for this target, move to next
        except Exception as e:
            continue
    else:
        print(f"✗ {target_name} ({tic_id}): No data found")

print(f"\nFound {len(working_targets)} targets with available data!")

# Create DataFrame of working targets
if working_targets:
    star_df = pd.DataFrame(working_targets)
    print("\nWorking targets:")
    for i, row in star_df.iterrows():
        print(f"  {row['target_name']}: {row['search_term']} ({row['k2_results']} K2)")
else:
    print("No targets found with available data.")
# Out:
# Loaded sample from mega target list!
# Shape: (5, 31)
# Targets with mission_source 'K2': 5
#
# Targets to search for K2 data:
#   HD 3167 b: TIC 318707987 (discovered by K2)
#   HD 3167 c: TIC 318707987 (discovered by K2)
#   K2-149 b: TIC 429035886 (discovered by K2)
#   K2-206 b: TIC 257392778 (discovered by K2)
#   K2-217 b: TIC 405333767 (discovered by K2)
#
# Testing searches...
# ✓ TIC 318707987: 1 K2 results
# ✓ TIC 318707987: 1 K2 results
# ✓ TIC 429035886: 1 K2 results
# ✓ TIC 257392778: 1 K2 results
# ✓ TIC 405333767: 1 K2 results
#
# Found 5 targets with available data!
#
# Working targets:
#   HD 3167 b: TIC 318707987 (1 K2)
#   HD 3167 c: TIC 318707987 (1 K2)
#   K2-149 b: TIC 429035886 (1 K2)
#   K2-206 b: TIC 257392778 (1 K2)
#   K2-217 b: TIC 405333767 (1 K2)

# %%
# Load the full mega target list
targets = pd.read_csv("C:\\Users\\smithlt\\Documents\\ASTR502\\ASTR502_Mega_Target_List.csv")

print(f"Loaded {len(targets)} total targets from CSV")
print(f"Columns available: {list(targets.columns)}")

# Check what mission sources we have
if 'mission_source' in targets.columns:
    print(f"\nMission sources in dataset:")
    print(targets['mission_source'].value_counts())
    
    # Filter for only Kepler targets
    kepler_targets = targets[targets['mission_source'] == 'Kepler'].copy()
    print(f"\nFound {len(kepler_targets)} Kepler targets!")
    
    if len(kepler_targets) > 0:
        print("\nFirst 5 Kepler targets:")
        for i, row in kepler_targets.head().iterrows():
            print(f"  {row['pl_name']}: {row['tic_id']}")
    else:
        print("No Kepler targets found in the dataset.")
        print("Let's check for targets that might have Kepler data...")
        
        # Look for targets that might have sy_kepmag (Kepler magnitude)
        if 'sy_kepmag' in targets.columns:
            kepler_mag_targets = targets[pd.notna(targets['sy_kepmag'])].copy()
            print(f"Found {len(kepler_mag_targets)} targets with Kepler magnitudes")
            if len(kepler_mag_targets) > 0:
                print("First 5 targets with Kepler magnitudes:")
                for i, row in kepler_mag_targets.head().iterrows():
                    print(f"  {row['pl_name']}: {row['tic_id']}, Kepler mag: {row['sy_kepmag']}")
                kepler_targets = kepler_mag_targets
else:
    print("No 'mission_source' column found. Let's look for other Kepler indicators...")
    
    # Look for targets that might have sy_kepmag
    if 'sy_kepmag' in targets.columns:
        kepler_targets = targets[pd.notna(targets['sy_kepmag'])].copy()
        print(f"Found {len(kepler_targets)} targets with Kepler magnitudes")
    else:
        print("No clear Kepler indicators found in the dataset.")
        kepler_targets = pd.DataFrame()

print(f"\nFinal Kepler target count: {len(kepler_targets)}")

# Test a few Kepler targets quickly to see what works
if len(kepler_targets) > 0:
    print("\nTesting search methods on first 3 Kepler targets...")
    test_sample = kepler_targets.head(5)
    
    working_kepler_targets = []
    
    for i, row in test_sample.iterrows():
        target_name = row['pl_name']
        tic_id = row['tic_id']
        
        print(f"\nTesting {target_name} ({tic_id}):")
        
        # Try different search strategies
        search_strategies = [
            f"{tic_id}",
            f"{tic_id}",
            target_name.split()[0] if len(target_name.split()) > 1 else target_name
        ]
        
        found_data = False
        for search_term in search_strategies:
            try:
                kepler_result = lk.search_lightcurve(search_term, author='Kepler')

                if len(kepler_result) > 0:
                    print(f"  ✓ '{search_term}': {len(kepler_result)} Kepler results")
                    working_kepler_targets.append({
                        'target_name': target_name,
                        'tic_id': tic_id,
                        'search_term': search_term,
                        'kepler_results': len(kepler_result),
                    })
                    found_data = True
                    break
                else:
                    print(f"  ✗ '{search_term}': No results")
            except Exception as e:
                print(f"  ✗ '{search_term}': Error - {e}")
        
        if not found_data:
            print(f"No data found for {target_name}")
    
    print(f"\n✓ Found {len(working_kepler_targets)} Kepler targets with available data")
    
    if working_kepler_targets:
        # Create DataFrame for processing
        kepler_star_df = pd.DataFrame(working_kepler_targets)
        print("\nReady to process these Kepler targets:")
        for i, row in kepler_star_df.iterrows():
            print(f"  {row['target_name']}: {row['search_term']} ({row['kepler_results']} Kepler)")
    else:
        print("No working Kepler targets found in the test sample")
else:
    print("No Kepler targets to test")
# Out:
# Loaded 4516 total targets from CSV
# Columns available: ['pl_name', 'hostname', 'gaia_dr3_id', 'gaia_dr2_id', 'tic_id', 'hd_name', 'ra', 'dec', 'sy_vmag', 'sy_jmag', 'sy_kmag', 'sy_tmag', 'sy_kepmag', 'sy_gaiamag', 'st_teff', 'st_logg', 'st_met', 'st_mass', 'st_rad', 'st_spectype', 'st_lum', 'st_age', 'st_ageerr1', 'st_ageerr2', 'st_rotp', 'pl_orbper', 'pl_rade', 'pl_trandur', 'disc_facility', 'disc_year', 'mission_source']
#
# Mission sources in dataset:
# mission_source
# Kepler    2762
# TESS       717
# K2         548
# WASP       168
# HAT        139
# Other      105
# CoRoT       34
# NGTS        22
# KELT        21
# Name: count, dtype: int64
#
# Found 2762 Kepler targets!
#
# First 5 Kepler targets:
#   Kepler-1629 b: TIC 351766445
#   Kepler-1445 b: TIC 351766604
#   Kepler-1286 b: TIC 351766517
#   Kepler-1835 b: TIC 351799800
#   Kepler-1341 b: TIC 123126460
#
# Final Kepler target count: 2762
#
# Testing search methods on first 3 Kepler targets...
#
# Testing Kepler-1629 b (TIC 351766445):
#   ✓ 'TIC 351766445': 18 Kepler results
#
# Testing Kepler-1445 b (TIC 351766604):
#   ✓ 'TIC 351766604': 18 Kepler results
#
# Testing Kepler-1286 b (TIC 351766517):
#   ✓ 'TIC 351766517': 9 Kepler results
#
# Testing Kepler-1835 b (TIC 351799800):
#   ✓ 'TIC 351799800': 9 Kepler results
#
# Testing Kepler-1341 b (TIC 123126460):
#   ✓ 'TIC 351799800': 9 Kepler results
#
# Testing Kepler-1341 b (TIC 123126460):
#   ✓ 'TIC 123126460': 17 Kepler results
#
# ✓ Found 5 Kepler targets with available data
#
# Ready to process these Kepler targets:
#   Kepler-1629 b: TIC 351766445 (18 Kepler)
#   Kepler-1445 b: TIC 351766604 (18 Kepler)
#   Kepler-1286 b: TIC 351766517 (9 Kepler)
#   Kepler-1835 b: TIC 351799800 (9 Kepler)
#   Kepler-1341 b: TIC 123126460 (17 Kepler)
#   ✓ 'TIC 123126460': 17 Kepler results
#
# ✓ Found 5 Kepler targets with available data
#
# Ready to process these Kepler targets:
#   Kepler-1629 b: TIC 351766445 (18 Kepler)
#   Kepler-1445 b: TIC 351766604 (18 Kepler)
#   Kepler-1286 b: TIC 351766517 (9 Kepler)
#   Kepler-1835 b: TIC 351799800 (9 Kepler)
#   Kepler-1341 b: TIC 123126460 (17 Kepler)

# %%
# Process the Kepler targets we found
if 'kepler_star_df' in locals() and len(kepler_star_df) > 0:
    print(f"Processing {len(kepler_star_df)} Kepler targets with available data...")

    best_periods = []
    successful_analyses = 0
    target_results = []

    for i, row in kepler_star_df.iterrows():
        target_name = row['target_name'] 
        search_term = row['search_term']
        tic_id = row['tic_id']
        
        print(f"\n{'='*50}")
        print(f"Processing target {i+1}/{len(kepler_star_df)}: {target_name}")
        print(f"TIC ID: {tic_id}, Search term: {search_term}")
        
        try:
            # Search for Kepler and K2 data
            kepler_search = lk.search_lightcurve(search_term, author='Kepler')
            k2_search = lk.search_lightcurve(search_term, author='K2')
            
            # Process Kepler data first if available
            if len(kepler_search) > 0:
                print(f"Found {len(kepler_search)} quarters of Kepler data")
                
                # Download first quarter only to keep it fast
                lc = kepler_search[0].download()
                
                if lc is not None:
                    mission_name = 'Kepler'
                    print(f"✓ Successfully downloaded Kepler lightcurve")
                    print(f"  Time span: {lc.time.min().value:.1f} - {lc.time.max().value:.1f} days")
                    print(f"  Data points: {len(lc.time)}")
                    
                    # Process the lightcurve
                    time = lc.time.value if hasattr(lc.time, "value") else np.asarray(lc.time)
                    flux = lc.flux.value if hasattr(lc.flux, "value") else np.asarray(lc.flux)

                    # remove NaNs / infinities
                    mask = np.isfinite(time) & np.isfinite(flux)
                    clean_time = time[mask]
                    clean_flux = flux[mask]

                    
                    if len(clean_time) > 100:  # Need enough points for analysis
                        print(f"  Clean data points: {len(clean_time)}")
                        
                        # Lomb-Scargle analysis
                        freq, power = LombScargle(clean_time, clean_flux).autopower(
                            minimum_frequency=1/80, maximum_frequency=10
                        )
                        
                        # Find peak
                        peak_freq = freq[np.argmax(power)]
                        peak_period = 1/peak_freq
                        peak_power = np.max(power)
                        
                        print(f"  ✓ Period analysis complete:")
                        print(f"    Peak period: {peak_period:.4f} days")
                        print(f"    Peak power: {peak_power:.4f}")
                        
                        # Store results
                        target_results.append({
                            'target_name': target_name,
                            'tic_id': tic_id,
                            'mission': mission_name,
                            'period': peak_period,
                            'power': peak_power,
                            'data_points': len(clean_time)
                        })
                        
                        best_periods.append(peak_period)
                        successful_analyses += 1
                        
                        # Quick plot
                        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
                        
                        # Lightcurve
                        lc.plot(ax=ax1)
                        ax1.set_title(f'{target_name} - Kepler Lightcurve')
                        
                        # Periodogram
                        ax2.plot(1/freq, power)
                        ax2.set_xlabel('Period (days)')
                        ax2.set_ylabel('Power')
                        ax2.set_title(f'Periodogram (Peak: {peak_period:.4f} days)')
                        ax2.axvline(peak_period, color='red', linestyle='--', alpha=0.7)
                        
                        plt.tight_layout()
                        plt.show()
                        
                    else:
                        print(f"Not enough clean data points ({len(clean_time)})")
                else:
                    print(f"Failed to download Kepler data")
                    
        except Exception as e:
            print(f"Error processing {target_name}: {e}")
            continue

    #final summary
    print(f"\n{'='*50}")
    print(f"FINAL SUMMARY")
    print(f"{'='*50}")
    print(f"Kepler targets processed: {len(kepler_star_df)}")
    print(f"Successful analyses: {successful_analyses}")
    
    if target_results:
        results_df = pd.DataFrame(target_results)
        print(f"\nSuccessful targets:")
        for i, row in results_df.iterrows():
            print(f"  {row['target_name']}: {row['period']:.4f} days ({row['mission']})")
        
        if len(best_periods) > 1:
            print(f"\nPeriod statistics:")
            print(f"  Average: {np.mean(best_periods):.4f} days")
            print(f"  Range: {np.min(best_periods):.4f} - {np.max(best_periods):.4f} days")
            print(f"  Median: {np.median(best_periods):.4f} days")
    else:
        print("No successful analyses completed")
        
else:
    print("No Kepler targets available. Please run the previous cell first to identify Kepler targets.")
# Out:
# Processing 5 Kepler targets with available data...
#
# ==================================================
# Processing target 1/5: Kepler-1629 b
# TIC ID: TIC 351766445, Search term: TIC 351766445
# Found 18 quarters of Kepler data
# ✓ Successfully downloaded Kepler lightcurve
#   Time span: 120.5 - 130.2 days
#   Data points: 473
#   Clean data points: 469
#   ✓ Period analysis complete:
#     Peak period: 6.3801 days
#     Peak power: 0.7350
#   ✓ Period analysis complete:
#     Peak period: 6.3801 days
#     Peak power: 0.7350
# ==================================================
# Processing target 2/5: Kepler-1445 b
# TIC ID: TIC 351766604, Search term: TIC 351766604
# Found 18 quarters of Kepler data
# ✓ Successfully downloaded Kepler lightcurve
#   Time span: 120.5 - 130.2 days
#   Data points: 473
#   Clean data points: 469
#   ✓ Period analysis complete:
#     Peak period: 10.5351 days
#     Peak power: 0.1896
# ==================================================
# Processing target 3/5: Kepler-1286 b
# TIC ID: TIC 351766517, Search term: TIC 351766517
# Found 9 quarters of Kepler data
# ✓ Successfully downloaded Kepler lightcurve
#   Time span: 131.5 - 165.0 days
#   Data points: 1626
#   Clean data points: 1624
#   ✓ Period analysis complete:
#     Peak period: 20.6817 days
#     Peak power: 0.0853
# ==================================================
# Processing target 4/5: Kepler-1835 b
# TIC ID: TIC 351799800, Search term: TIC 351799800
# Found 9 quarters of Kepler data
# ✓ Successfully downloaded Kepler lightcurve
#   Time span: 131.5 - 165.0 days
#   Data points: 1626
#   Clean data points: 1624
#   ✓ Period analysis complete:
#     Peak period: 80.0000 days
#     Peak power: 0.0836
# ==================================================
# Processing target 5/5: Kepler-1341 b
# TIC ID: TIC 123126460, Search term: TIC 123126460
# Found 17 quarters of Kepler data
# ✓ Successfully downloaded Kepler lightcurve
#   Time span: 131.5 - 165.0 days
#   Data points: 1626
#   Clean data points: 1624
#   ✓ Period analysis complete:
#     Peak period: 23.5980 days
#     Peak power: 0.8405
# ==================================================
# FINAL SUMMARY
# ==================================================
# Kepler targets processed: 5
# Successful analyses: 5
#
# Successful targets:
#   Kepler-1629 b: 6.3801 days (Kepler)
#   Kepler-1445 b: 10.5351 days (Kepler)
#   Kepler-1286 b: 20.6817 days (Kepler)
#   Kepler-1835 b: 80.0000 days (Kepler)
#   Kepler-1341 b: 23.5980 days (Kepler)
#
# Period statistics:
#   Average: 28.2390 days
#   Range: 6.3801 - 80.0000 days
#   Median: 20.6817 days
